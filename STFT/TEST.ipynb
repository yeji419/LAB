# %%
import numpy as np
import librosa
import librosa.display
import matplotlib.pyplot as plt
import math
import import_ipynb
import soundfile as sf
from STFTAlgorithm import STFT, ISTFT, GriffinLim

# %%
t = np.linspace(0, 10*np.pi, 1001)[:-1]
sin = np.sin(t)
plt.plot(t,sin)

# %%
sin_stft = STFT(sin, 32, 16)
print(sin_stft.shape)
# Out:
# (63, 32)

# %%
sin_libstft =  librosa.stft(sin, n_fft=32, hop_length=16, window='hamming')
print(sin_libstft.shape)
# Out:
# (17, 63)

# %%
sin_half = (sin_stft[:,:17]).T
print(sin_half.shape)
# Out:
# (17, 63)

# %%
sin_lib_log_spectrogram = librosa.amplitude_to_db(np.abs(sin_libstft))
librosa.display.specshow(sin_lib_log_spectrogram, sr=10, hop_length=16)

# %%
sin_log_spectrogram = librosa.amplitude_to_db(np.abs(sin_half))
librosa.display.specshow(sin_log_spectrogram, sr=10, hop_length=16)

# %%
error = sin_half - sin_libstft
plt.plot(error[1])
# Out:
# C:\Users\yegee\anaconda3\lib\site-packages\numpy\core\_asarray.py:102: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
JCT_sig, sr = librosa.load('JCT.wav' , sr = 16000)
window_length = 512
shift = int(window_length / 2)
JCT_stft = STFT(JCT_sig, window_length, shift)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-57-42387aa0f10c> in <module>
#       2 window_length = 512
#       3 shift = int(window_length / 2)
# ----> 4 JCT_stft = STFT(JCT_sig, window_length, shift)
#
# ~\Desktop\STFT\STFTAlgorithm.ipynb in STFT(sig, window_length, shift)
#
# KeyboardInterrupt:

# %%
Mask = np.exp(np.pi*1j)
mstft = Mask * stft

# %%
result = GriffinLim(mstft, window_length, shift)
# Out:
# 0
# 256
# 512
# 768
# 1024
# 1280
# 1536
# 1792
# 2048
# 2304
# 2560
# 2816
# 3072
# 3328
# 3584
# 3840
# 4096
# 4352
# 4608
# 4864
# 5120
# 5376
# 5632
# 5888
# 6144
# 6400
# 6656
# 6912
# 7168
# 7424
# 7680
# 7936
# 8192
# 8448
# 8704
# 8960
# 9216
# 9472
# 9728
# 9984
# 10240
# 10496
# 10752
# 11008
# 11264
# 11520
# 11776
# 12032
# 12288
# 12544
# 12800
# 13056
# 13312
# 13568
# 13824
# 14080
# 14336
# 14592
# 14848
# 15104
# 15360
# 15616
# 15872
# 16128
# 16384
# 16640
# 16896
# 17152
# 17408
# 17664
# 17920
# 18176
# 18432
# 18688
# 18944
# 19200
# 19456
# 19712
# 19968
# 20224
# 20480
# 20736
# 20992
# 21248
# 21504
# 21760
# 22016
# 22272
# 22528
# 22784
# 23040
# 23296
# 23552
# 23808
# 24064
# 24320
# 24576
# 24832
# 25088
# 25344
# 25600
# 25856
# 26112
# 26368
# 26624
# 26880
# 27136
# 27392
# 27648
# 27904
# 28160
# 28416
# 28672
# 28928
# 29184
# 29440
# 29696
# 29952
# 30208
# 30464
# 30720
# 30976
# 31232
# 31488
# 31744
# 32000
# 32256
# 32512
# 32768
# 33024
# ...

# %%
istft = librosa.istft(stft)

# %%
plt.plot(sig, label='Original Signal')
plt.plot(result,label='Griffin-Lim Algorithm')
plt.plot(imstft, label='IMSTFT')
plt.plot(istft, label ='librosa ISTFT')
plt.legend()

# %%
# sf.write('result2.wav', result, sr, 'PCM_24')
sf.write('librosa istft_about stft 2.wav', istft, sr, 'PCM_24')

# %%
imstft = IMSTFT(mstft, window_length, shift)
# Out:
# <string>:30: ComplexWarning: Casting complex values to real discards the imaginary part

# %%
sf.write('imstft 2.wav', imstft, sr, 'PCM_24')

# %%
plt.plot(stft[2])
plt.plot(mstft[2])
# Out:
# C:\Users\yegee\anaconda3\lib\site-packages\numpy\core\_asarray.py:102: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# C:\Users\yegee\anaconda3\lib\site-packages\numpy\core\_asarray.py:102: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

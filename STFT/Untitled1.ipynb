# %%
import numpy as np
import librosa
import librosa.display
import matplotlib.pyplot as plt
import math
import import_ipynb
import soundfile as sf
from STFTAlgorithm import STFT, ISTFT, GriffinLim
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-81523545848c> in <module>
#       6 import import_ipynb
#       7 import soundfile as sf
# ----> 8 from STFTAlgorithm import STFT, ISTFT, GriffinLim
#
# ImportError: cannot import name 'STFT' from 'STFTAlgorithm' (STFTAlgorithm.ipynb)

# %%
plt.plot(np.hamming(50))
